# %%
import pandas as pd

team_stats = pd.read_csv('/Users/levkondratchik/Documents/GitHub/clustering-players-profiles/data/standard_team_stats.csv')

team_stats.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0              Squad               # Pl                Age               Poss
# 1            Arsenal                 25               25.8               56.9
# 2        Aston Villa                 28               27.0               50.5
# 3        Bournemouth                 29               25.1               48.5
# 4          Brentford                 28               25.8               47.9
#
#   Playing Time Playing Time.1 Playing Time.2 Playing Time.3 Performance  \
# 0           MP         Starts            Min            90s         Gls
# 1           38            418           3420           38.0          67
# 2           38            418           3420           38.0          56
# 3           38            418           3420           38.0          57
# 4           38            418           3420           38.0          65
#
# ...

# %%
# Переименование последних двух колонок (32 и 33) как League и Ca
team_stats.rename(columns={32: 'League', 33: 'standard'}, inplace=True)

team_stats.head()
# Способ 1: По индексу колонок
team_stats.rename(columns={team_stats.columns[32]: 'League', team_stats.columns[33]: 'Category'}, inplace=True)


team_stats.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0              Squad               # Pl                Age               Poss
# 1            Arsenal                 25               25.8               56.9
# 2        Aston Villa                 28               27.0               50.5
# 3        Bournemouth                 29               25.1               48.5
# 4          Brentford                 28               25.8               47.9
#
#   Playing Time Playing Time.1 Playing Time.2 Playing Time.3 Performance  \
# 0           MP         Starts            Min            90s         Gls
# 1           38            418           3420           38.0          67
# 2           38            418           3420           38.0          56
# 3           38            418           3420           38.0          57
# 4           38            418           3420           38.0          65
#
# ...

# %%
team_stats.drop(columns = [team_stats.columns[33]], inplace=True)

# %%
team_stats.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0              Squad               # Pl                Age               Poss
# 1            Arsenal                 25               25.8               56.9
# 2        Aston Villa                 28               27.0               50.5
# 3        Bournemouth                 29               25.1               48.5
# 4          Brentford                 28               25.8               47.9
#
#   Playing Time Playing Time.1 Playing Time.2 Playing Time.3 Performance  \
# 0           MP         Starts            Min            90s         Gls
# 1           38            418           3420           38.0          67
# 2           38            418           3420           38.0          56
# 3           38            418           3420           38.0          57
# 4           38            418           3420           38.0          65
#
# ...

# %%
# Out:
# Исправленные названия последних столбцов:
# Предпоследний: 'League'
# Последний: 'Category'
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0              Squad               # Pl                Age               Poss
# 1            Arsenal                 25               25.8               56.9
# 2        Aston Villa                 28               27.0               50.5
# 3        Bournemouth                 29               25.1               48.5
# 4          Brentford                 28               25.8               47.9
#
#   Playing Time Playing Time.1 Playing Time.2 Playing Time.3 Performance  \
# 0           MP         Starts            Min            90s         Gls
# 1           38            418           3420           38.0          67
# 2           38            418           3420           38.0          56
# 3           38            418           3420           38.0          57
# ...
